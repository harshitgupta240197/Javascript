# %% [markdown]
# # CONST
# #### The JavaScript const keyword declares block-scoped variables whose values cannot be reassigned. It creates an immutable reference to a value, making it the modern standard for variables that should remain unchanged throughout your application's lifetime
# ```js
# const taxRate = 0.15; // Correct initialization
#
# taxRate = 0.20;
# // ❌ TypeError: Assignment to constant variable.
#
# ```
